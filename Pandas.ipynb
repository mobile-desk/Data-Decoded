# %%
# Donate: https://flutterwave.com/donate/owbkr5asntut

# %% [markdown]
# # Install pandas

# %%
#  pip install pandas

# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # Create DataSet

# %%
d = {
    'Name': ['Praise', 'Chibudom', 'Obasi'],
    'Age': [10, 11, 12]
}

v = pd.DataFrame(d)

# %%
v
# Out:
#        Name  Age
# 0    Praise   10
# 1  Chibudom   11
# 2     Obasi   12

# %%
# series are one dimensional arrays
a = [1,2,3]
h = pd.Series(a)

h
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# # load csv file

# %%
df = pd.read_csv('employee.csv')
# employee.csv file will be provided

# %%
df.head(6)
# Out:
#    Employee_ID             Name  Age   Position    Salary  Start_Date
# 0         1001         John Doe   35    Manager  75000.50   6/15/2018
# 1         1002       Jane Smith   28  Developer  60000.75   2/20/2019
# 2         1003  Michael Johnson   42    Analyst  55000.25  11/10/2017
# 3         1004      Emily Davis   30   Designer  58000.00    4/5/2020
# 4         1005     Robert Brown   45   Engineer  80000.20   9/30/2016
# 5         1006     Sarah Wilson   37   Marketer  62000.80  12/12/2018

# %%
df.tail()
# Out:
#     Employee_ID             Name  Age               Position    Salary  \
# 55         1056  Savannah Carter   42            HR Director  78000.75
# 56         1057      Luke Rivera   34      Software Engineer  75000.20
# 57         1058       Bella Ross   28         UX/UI Designer  64000.35
# 58         1059        Ethan Cox   37  Systems Administrator  67000.50
# 59         1060     Madison Reed   30      Marketing Analyst  60000.80
#
#     Start_Date
# 55   6/20/2017
# 56   1/15/2018
# 57   9/30/2019
# 58   4/12/2018
# 59  11/25/2020

# %% [markdown]
# # Reading Data

# %% [markdown]
# ## Get all the headers

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Position', 'Salary', 'Start_Date'], dtype='object')

# %% [markdown]
# ## Get the shape

# %%
df.shape
# Out:
# (60, 6)

# %% [markdown]
# ## Get data by columns

# %%
df['Age'].head(10)
# Out:
# 0    35
# 1    28
# 2    42
# 3    30
# 4    45
# 5    37
# 6    33
# 7    29
# 8    38
# 9    31
# Name: Age, dtype: int64

# %%
df[['Name','Age']].head(10)
# Out:
#                 Name  Age
# 0           John Doe   35
# 1         Jane Smith   28
# 2    Michael Johnson   42
# 3        Emily Davis   30
# 4       Robert Brown   45
# 5       Sarah Wilson   37
# 6          David Lee   33
# 7      Amanda Taylor   29
# 8  Christopher Clark   38
# 9    Lauren Martinez   31

# %% [markdown]
# ## Print rows

# %%
df.iloc[5:15:2] #you can also print an individual rows
# Out:
#     Employee_ID             Name  Age           Position    Salary  Start_Date
# 5          1006     Sarah Wilson   37           Marketer  62000.80  12/12/2018
# 7          1008    Amanda Taylor   29      HR Specialist  53000.50  10/15/2020
# 9          1010  Lauren Martinez   31  Financial Analyst  60000.40   6/20/2019
# 11         1012  Stephanie White   27  Marketing Manager  65000.25   7/10/2020
# 13         1014    Emma Thompson   32   Graphic Designer  57000.35   10/5/2019

# %% [markdown]
# ## Access all data in a row, row by row

# %%
for index, row in df.iterrows():
    print(index, row)
    print('\n')
# Out:
# 0 Employee_ID         1001
# Name            John Doe
# Age                   35
# Position         Manager
# Salary           75000.5
# Start_Date     6/15/2018
# Name: 0, dtype: object
#
#
# 1 Employee_ID          1002
# Name           Jane Smith
# Age                    28
# Position        Developer
# Salary           60000.75
# Start_Date      2/20/2019
# Name: 1, dtype: object
#
#
# 2 Employee_ID               1003
# Name           Michael Johnson
# Age                         42
# Position               Analyst
# Salary                55000.25
# Start_Date          11/10/2017
# Name: 2, dtype: object
#
#
# 3 Employee_ID           1004
# Name           Emily Davis
# Age                     30
# Position          Designer
# Salary             58000.0
# Start_Date        4/5/2020
# Name: 3, dtype: object
#
#
# 4 Employee_ID            1005
# Name           Robert Brown
# Age                      45
# Position           Engineer
# Salary              80000.2
# ...

# %% [markdown]
# ## Find if a data exist within a column

# %%
df.loc[df['Name'] == 'John Doe']
# Out:
#    Employee_ID      Name  Age Position   Salary Start_Date
# 0         1001  John Doe   35  Manager  75000.5  6/15/2018

# %% [markdown]
# ## Describing data

# %%
df.describe()
# Out:
#        Employee_ID        Age        Salary
# count    60.000000  60.000000     60.000000
# mean   1030.500000  34.450000  67417.210833
# std      17.464249   5.466152   8706.733638
# min    1001.000000  26.000000  53000.500000
# 25%    1015.750000  30.000000  60750.387500
# 50%    1030.500000  34.000000  66000.225000
# 75%    1045.250000  38.250000  75000.425000
# max    1060.000000  45.000000  85000.900000

# %% [markdown]
# ## Sort

# %%
df.sort_values('Position') #add ascending=False to reverse
# Out:
#     Employee_ID                Name  Age                      Position  \
# 21         1022       Sophia Carter   31                    Accountant
# 2          1003     Michael Johnson   42                       Analyst
# 16         1017        Nathan Scott   41              Business Analyst
# 40         1041       Samuel Brooks   45  Business Development Manager
# 48         1049        Leah Bennett   26               Content Manager
# 29         1030     Samantha Rivera   27                Content Writer
# 32         1033      Alexander Hill   38                  Data Analyst
# 19         1020     Chloe Rodriguez   29                  Data Analyst
# 8          1009   Christopher Clark   38                Data Scientist
# 53         1054        Kylie Hughes   38                Data Scientist
# 26         1027          Lucas Hall   37        Database Administrator
# 42         1043        Dylan Powell   37              Database Analyst
# ...

# %% [markdown]
# ## DOuble sorting

# %%
df.sort_values(['Position', 'Age'], ascending=[1,0]) # 1 means lowest to highest
# Out:
#     Employee_ID                Name  Age                      Position  \
# 21         1022       Sophia Carter   31                    Accountant
# 2          1003     Michael Johnson   42                       Analyst
# 16         1017        Nathan Scott   41              Business Analyst
# 40         1041       Samuel Brooks   45  Business Development Manager
# 48         1049        Leah Bennett   26               Content Manager
# 29         1030     Samantha Rivera   27                Content Writer
# 32         1033      Alexander Hill   38                  Data Analyst
# 19         1020     Chloe Rodriguez   29                  Data Analyst
# 8          1009   Christopher Clark   38                Data Scientist
# 53         1054        Kylie Hughes   38                Data Scientist
# 26         1027          Lucas Hall   37        Database Administrator
# 42         1043        Dylan Powell   37              Database Analyst
# ...

# %% [markdown]
# # Make Changes

# %%
# note: this does not affect the actual file

# %% [markdown]
# ## adding a new column

# %%
df['Interest'] = df['Salary'] * 0.2

# %%
df.head()
# Out:
#    Employee_ID             Name  Age   Position    Salary  Start_Date  \
# 0         1001         John Doe   35    Manager  75000.50   6/15/2018
# 1         1002       Jane Smith   28  Developer  60000.75   2/20/2019
# 2         1003  Michael Johnson   42    Analyst  55000.25  11/10/2017
# 3         1004      Emily Davis   30   Designer  58000.00    4/5/2020
# 4         1005     Robert Brown   45   Engineer  80000.20   9/30/2016
#
#    Interest
# 0  15000.10
# 1  12000.15
# 2  11000.05
# 3  11600.00
# 4  16000.04

# %% [markdown]
# ## remove a column

# %%
df.drop(columns=['Interest'],  inplace=True)
df
# Out:
#     Employee_ID                Name  Age                      Position  \
# 0          1001            John Doe   35                       Manager
# 1          1002          Jane Smith   28                     Developer
# 2          1003     Michael Johnson   42                       Analyst
# 3          1004         Emily Davis   30                      Designer
# 4          1005        Robert Brown   45                      Engineer
# 5          1006        Sarah Wilson   37                      Marketer
# 6          1007           David Lee   33               Project Manager
# 7          1008       Amanda Taylor   29                 HR Specialist
# 8          1009   Christopher Clark   38                Data Scientist
# 9          1010     Lauren Martinez   31             Financial Analyst
# 10         1011   Matthew Hernandez   39             Software Engineer
# 11         1012     Stephanie White   27             Marketing Manager
# ...

# %% [markdown]
# # Saving our data

# %%
df.to_csv('pandas.csv')

# %%
# to remove index from csv whewn saving
df.to_csv('no_index_pandas.csv', index=False)

#files provided

# %% [markdown]
# # FIltering Data

# %% [markdown]
# ## find/search

# %%
df.loc[df['Name'] == "John"]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Name, Age, Position, Salary, Start_Date]
# Index: []

# %%
df.loc[(df['Name'] == "John Doe") | (df['Age'] == 4)]
# Out:
#    Employee_ID      Name  Age Position   Salary Start_Date
# 0         1001  John Doe   35  Manager  75000.5  6/15/2018

# %% [markdown]
# ## Find using contain

# %%
df.loc[(df['Name'].str.contains('John'))]
# Out:
#    Employee_ID             Name  Age Position    Salary  Start_Date
# 0         1001         John Doe   35  Manager  75000.50   6/15/2018
# 2         1003  Michael Johnson   42  Analyst  55000.25  11/10/2017

# %%
f = df.loc[(~df['Name'].str.contains('a'))]
f
# Out:
#     Employee_ID                Name  Age                    Position  \
# 0          1001            John Doe   35                     Manager
# 4          1005        Robert Brown   45                    Engineer
# 19         1020     Chloe Rodriguez   29                Data Analyst
# 27         1028          Lily Green   30            Technical Writer
# 39         1040          Emily Ross   34        Social Media Manager
# 45         1046       Justin Butler   32               Web Developer
# 47         1048  Christopher Miller   43                  IT Manager
# 50         1051          Avery Long   29  Technical Support Engineer
# 51         1052          Zoe Murphy   44  Quality Control Specialist
# 53         1054        Kylie Hughes   38              Data Scientist
#
#       Salary Start_Date
# 0   75000.50  6/15/2018
# 4   80000.20  9/30/2016
# 19  56000.30  6/12/2020
# 27  61000.25  2/20/2020
# 39  61000.55  12/5/2018
# 45  69000.90  11/5/2019
# 47  80000.40   1/5/2017
# ...

# %%
f = f.reset_index(drop = True)

# %%
f
# Out:
#    index  Employee_ID                Name  Age                    Position  \
# 0      0         1001            John Doe   35                     Manager
# 1      4         1005        Robert Brown   45                    Engineer
# 2     19         1020     Chloe Rodriguez   29                Data Analyst
# 3     27         1028          Lily Green   30            Technical Writer
# 4     39         1040          Emily Ross   34        Social Media Manager
# 5     45         1046       Justin Butler   32               Web Developer
# 6     47         1048  Christopher Miller   43                  IT Manager
# 7     50         1051          Avery Long   29  Technical Support Engineer
# 8     51         1052          Zoe Murphy   44  Quality Control Specialist
# 9     53         1054        Kylie Hughes   38              Data Scientist
#
#      Salary Start_Date
# 0  75000.50  6/15/2018
# 1  80000.20  9/30/2016
# 2  56000.30  6/12/2020
# 3  61000.25  2/20/2020
# ...

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ## Remove rows with blank cells

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## fill empty cells

# %%
df.fillna('new value')
# Out:
#     Employee_ID                Name  Age                      Position  \
# 0          1001            John Doe   35                       Manager
# 1          1002          Jane Smith   28                     Developer
# 2          1003     Michael Johnson   42                       Analyst
# 3          1004         Emily Davis   30                      Designer
# 4          1005        Robert Brown   45                      Engineer
# 5          1006        Sarah Wilson   37                      Marketer
# 6          1007           David Lee   33               Project Manager
# 7          1008       Amanda Taylor   29                 HR Specialist
# 8          1009   Christopher Clark   38                Data Scientist
# 9          1010     Lauren Martinez   31             Financial Analyst
# 10         1011   Matthew Hernandez   39             Software Engineer
# 11         1012     Stephanie White   27             Marketing Manager
# ...

# %% [markdown]
# ## To discover duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
# you can make it specific to aq column

# %% [markdown]
# ## drop duplicates

# %%
df.drop_duplicates()
# Out:
#     Employee_ID                Name  Age                      Position  \
# 0          1001            John Doe   35                       Manager
# 1          1002          Jane Smith   28                     Developer
# 2          1003     Michael Johnson   42                       Analyst
# 3          1004         Emily Davis   30                      Designer
# 4          1005        Robert Brown   45                      Engineer
# 5          1006        Sarah Wilson   37                      Marketer
# 6          1007           David Lee   33               Project Manager
# 7          1008       Amanda Taylor   29                 HR Specialist
# 8          1009   Christopher Clark   38                Data Scientist
# 9          1010     Lauren Martinez   31             Financial Analyst
# 10         1011   Matthew Hernandez   39             Software Engineer
# 11         1012     Stephanie White   27             Marketing Manager
# ...

# %% [markdown]
# # Group by

# %%
df.groupby(['Age']).first()
# Out:
#      Employee_ID               Name              Position    Salary  \
# Age
# 26          1016      Olivia Garcia    Software Developer  61000.45
# 27          1012    Stephanie White     Marketing Manager  65000.25
# 28          1002         Jane Smith             Developer  60000.75
# 29          1008      Amanda Taylor         HR Specialist  53000.50
# 30          1004        Emily Davis              Designer  58000.00
# 31          1010    Lauren Martinez     Financial Analyst  60000.40
# 32          1014      Emma Thompson      Graphic Designer  57000.35
# 33          1007          David Lee       Project Manager  70000.00
# 34          1015       Aaron Harris       Product Manager  77000.60
# 35          1001           John Doe               Manager  75000.50
# 36          1019      Brandon Evans  Marketing Specialist  63000.20
# 37          1006       Sarah Wilson              Marketer  62000.80
# 38          1009  Christopher Clark        Data Scientist  85000.60
# ...

# %% [markdown]
# # Aggregrating

# %%
df.aggregate(['sum', 'min'])
# Out:
#      Employee_ID                                               Name   Age  \
# sum        61830  John DoeJane SmithMichael JohnsonEmily DavisRo...  2067
# min         1001                                       Aaron Harris    26
#
#                                               Position      Salary  \
# sum  ManagerDeveloperAnalystDesignerEngineerMarkete...  4045032.65
# min                                         Accountant    53000.50
#
#                                             Start_Date
# sum  6/15/20182/20/201911/10/20174/5/20209/30/20161...
# min                                          1/15/2018

# %%
df.groupby(['Age']).sum()
# Out:
#      Employee_ID                                               Name  \
# Age
# 26          2065                          Olivia GarciaLeah Bennett
# 27          4136  Stephanie WhiteSamantha RiveraWilliam StewartN...
# 28          4126         Jane SmithMia PerezGrace ColemanBella Ross
# 29          4111  Amanda TaylorChloe RodriguezHannah BaileyAvery...
# 30          4136      Emily DavisLily GreenLillian WardMadison Reed
# 31          4121  Lauren MartinezSophia CarterAbigail CooperJaso...
# 32          3086               Emma ThompsonElla LopezJustin Butler
# 33          3059               David LeeGrace WalkerVictoria Turner
# 34          3112                  Aaron HarrisEmily RossLuke Rivera
# 35          4105  John DoeWilliam AllenIsaac StewartBrandon Sanders
# 36          3103             Brandon EvansNicholas TorresHailey Cox
# 37          4135        Sarah WilsonLucas HallDylan PowellEthan Cox
# 38          3096        Christopher ClarkAlexander HillKylie Hughes
# ...

# %%
df.groupby(['Age']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# ...

# %%
df.groupby(['Age']).agg({'Age': 'mean'})
# Out:
#       Age
# Age
# 26   26.0
# 27   27.0
# 28   28.0
# 29   29.0
# 30   30.0
# 31   31.0
# 32   32.0
# 33   33.0
# 34   34.0
# 35   35.0
# 36   36.0
# 37   37.0
# 38   38.0
# 39   39.0
# 40   40.0
# 41   41.0
# 42   42.0
# 43   43.0
# 44   44.0
# 45   45.0

# %%
df.groupby(['Age']).mean(numeric_only = True)
# Out:
#      Employee_ID        Salary
# Age
# 26   1032.500000  59500.500000
# 27   1034.000000  62500.562500
# 28   1031.500000  62750.562500
# 29   1027.750000  61250.400000
# 30   1034.000000  59750.462500
# 31   1030.250000  59000.562500
# 32   1028.666667  65000.666667
# 33   1019.666667  62333.816667
# 34   1037.333333  71000.450000
# 35   1026.250000  73000.662500
# 36   1034.333333  63666.900000
# 37   1033.750000  67000.600000
# 38   1032.000000  77000.583333
# 39   1027.000000  77334.183333
# 40   1024.000000  71500.550000
# 41   1017.000000  64000.800000
# 42   1032.333333  70333.900000
# 43   1034.500000  79000.400000
# 44   1040.500000  79000.700000
# 45   1023.000000  81000.400000
